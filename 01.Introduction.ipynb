# %% [markdown]
# # Introduction

# %% [markdown]
# Note: These materials are mostly based on **[SciPy 2018 Scikit-learn Tutorial](https://github.com/amueller/scipy-2018-sklearn)**

# %% [markdown]
# ## Python
#
# Python is an interpreted, high-level and general-purpose programming language.
#
# ## Why use Python for  data science & machine learning?
#
# **open-source**
#
# Python is an open-source programming language and is supported by a lot of resources and high-quality documentation
#
#
# **The simplicity**
#
#
# Because of the simplicity of Python developers spend more time thinking about the problem they’re trying to solve and less time thinking about language complexities or deciphering code left by others.
#
#
# **Extensive selection of libraries and frameworks**
#
#
# One of the aspects that makes Python such a popular choice in general, is its hug amount of libraries and frameworks that facilitate coding and save development time.
#
#
#
# ## What are the most popular Python libraries for data science & machine learning?
#
#
# 1- **NumPy** is a Python library used for working with arrays. It also has functions for working in domain of linear algebra, fourier transform, and matrices.
#
#
# 2- **SciPy** is a library that uses NumPy for more mathematical functions in scientific programming, including linear algebra, integration (calculus), ordinary differential equation solving, and signal processing.
#
#
# 3- **Pandas** allows various data manipulation operations such as merging, reshaping, selecting, as well as data cleaning, and data wrangling features.
#
#
# 4- **matplotlib** is a powerful plotting library.
#
#
# 5- **scikit-learn** contains a lot of efficient tools for machine learning and statistical modeling including classification, regression, clustering and dimensionality reduction.
#
#
#
#
# ## What is Jupyter Notebook?
# **Jupyter Notebook** is an open-source web application that allows you to create and share documents that contain live code, equations, visualizations and narrative text.
#
#
# Let’s try it! Click on the box cell (Hello World!) and then run the cell by pressing [shift] + [Enter] or by pressing the "play" button in the menu.

# %%
print('Hello World!');
# Out:
# Hello World!

# %% [markdown]
# It also be able to keep results and data. Run the next lines one by one:

# %%
a = 'Hello';

# %%
b = ' World!';

# %%
print(a + b);
# Out:
# Hello World!

# %% [markdown]
# The data are still in the page. You can print data by simply write the variable name. Try this one:

# %%
a
# Out:
# 'Hello'

# %% [markdown]
# Voilà!

# %% [markdown]
# Let's back to Python Libraries.

# %% [markdown]
# # NumPy

# %% [markdown]
# Manipulating numpy arrays is an important part of doing machine learning (or, really, any type of scientific computation) in python. This will likely be a short review for most. In any case, let's quickly go through some of the most important features.

# %%
import numpy as np

# Setting a random seed for reproducibility
rnd = np.random.RandomState(seed=123)

# Generating a random array
X = rnd.uniform(low=0.0, high=1.0, size=(3, 5))  # a 3 x 5 array

print(X)
# Out:
# [[0.69646919 0.28613933 0.22685145 0.55131477 0.71946897]
#  [0.42310646 0.9807642  0.68482974 0.4809319  0.39211752]
#  [0.34317802 0.72904971 0.43857224 0.0596779  0.39804426]]

# %% [markdown]
# (Note that NumPy arrays use 0-indexing just like other data structures in Python.)

# %%
# Accessing elements

# get a single element 
# (here: an element in the first row and column)
print(X[0, 0])
# Out:
# 0.6964691855978616

# %%
# get a row 
# (here: 2nd row)
print(X[1])
# Out:
# [0.42310646 0.9807642  0.68482974 0.4809319  0.39211752]

# %%
# get a column
# (here: 2nd column)
print(X[:, 1])
# Out:
# [0.28613933 0.9807642  0.72904971]

# %%
# Transposing an array
print(X.T)
# Out:
# [[0.69646919 0.42310646 0.34317802]
#  [0.28613933 0.9807642  0.72904971]
#  [0.22685145 0.68482974 0.43857224]
#  [0.55131477 0.4809319  0.0596779 ]
#  [0.71946897 0.39211752 0.39804426]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Creating a row vector
# of evenly spaced numbers over a specified interval.
y = np.linspace(0, 12, 5)
print(y)
# Out:
# [ 0.  3.  6.  9. 12.]

# %%
# Turning the row vector into a column vector
print(y[:, np.newaxis])
# Out:
# [[ 0.]
#  [ 3.]
#  [ 6.]
#  [ 9.]
#  [12.]]

# %%
# Getting the shape or reshaping an array

# Generating a random array
rnd = np.random.RandomState(seed=123)
X = rnd.uniform(low=0.0, high=1.0, size=(3, 5))  # a 3 x 5 array

print(X.shape)
# Out:
# (3, 5)

# %%
# reshape X to be of size (3, 5)
X_reshaped = X.reshape(5, 3)
print(X_reshaped)
# Out:
# [[0.69646919 0.28613933 0.22685145]
#  [0.55131477 0.71946897 0.42310646]
#  [0.9807642  0.68482974 0.4809319 ]
#  [0.39211752 0.34317802 0.72904971]
#  [0.43857224 0.0596779  0.39804426]]

# %%
# Indexing by an array of integers (fancy indexing)
indices = np.array([3, 1, 0])
print(indices)
X[:, indices]
# Out:
# [3 1 0]
# array([[0.55131477, 0.28613933, 0.69646919],
#        [0.4809319 , 0.9807642 , 0.42310646],
#        [0.0596779 , 0.72904971, 0.34317802]])

# %% [markdown]
# There is much, much more to know, but these few operations are fundamental to what we'll do during this tutorial.

# %% [markdown]
# # matplotlib

# %% [markdown]
# Another important part of machine learning is the visualization of data. The most common tool for this in Python is matplotlib. It is an extremely flexible package, and we will go over some basics here.
#
# Since we are using Jupyter notebooks, let us use one of IPython's convenient built-in "magic functions", the "matoplotlib inline" mode, which will draw the plots directly inside the notebook.

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
# Plotting a line
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x));

# %%
# Scatter-plot points
x = np.random.normal(size=500)
y = np.random.normal(size=500)
plt.scatter(x, y);

# %%
# Showing images using imshow
# - note that origin is at the top-left by default!

x = np.linspace(1, 12, 100)
y = x[:, np.newaxis]

im = y * np.sin(x) * np.cos(y)
print(im.shape)

plt.imshow(im);
# Out:
# (100, 100)

# %%
# Contour plots 
# - note that origin here is at the bottom-left by default!
plt.contour(im);
